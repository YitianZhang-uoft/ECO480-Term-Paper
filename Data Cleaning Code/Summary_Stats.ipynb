# %%
import pandas as pd

# %%
# application_train - First Dataset
application_train = pd.read_csv('application_train.csv')

# %%
# Missing Data
missing = pd.DataFrame(application_train.isnull().sum())
missing
# Out:
#                                 0
# SK_ID_CURR                      0
# TARGET                          0
# NAME_CONTRACT_TYPE              0
# CODE_GENDER                     0
# FLAG_OWN_CAR                    0
# ...                           ...
# AMT_REQ_CREDIT_BUREAU_DAY   41519
# AMT_REQ_CREDIT_BUREAU_WEEK  41519
# AMT_REQ_CREDIT_BUREAU_MON   41519
# AMT_REQ_CREDIT_BUREAU_QRT   41519
# AMT_REQ_CREDIT_BUREAU_YEAR  41519
#
# [122 rows x 1 columns]

# %%
# Summary Statistics
X_describe = application_train.describe(include='all').T

result = pd.concat([X_describe], axis=0).rename(columns={'count': 'Non-missing Count', 'mean': 'Mean', 'std': 'Standard Deviation', 'min': 'Minimum', '25%': '25th percentile', '50%': '50th percentile', '75%': '75th percentile', 'max': 'Maximum', 'unique': 'Unique Values Count', 'top': 'Mode', 'freq': 'Mode Frequency'})
result['Missing Count'] = pd.concat([missing], axis=0)
result['Data Type'] = pd.concat([application_train.dtypes], axis=0)

# Display the result
pd.set_option('display.max_rows', None)
display(result)
# Out:
#                              Non-missing Count Unique Values Count  \
# SK_ID_CURR                            307511.0                 NaN
# TARGET                                307511.0                 NaN
# NAME_CONTRACT_TYPE                      307511                   2
# CODE_GENDER                             307511                   3
# FLAG_OWN_CAR                            307511                   2
# FLAG_OWN_REALTY                         307511                   2
# CNT_CHILDREN                          307511.0                 NaN
# AMT_INCOME_TOTAL                      307511.0                 NaN
# AMT_CREDIT                            307511.0                 NaN
# AMT_ANNUITY                           307499.0                 NaN
# AMT_GOODS_PRICE                       307233.0                 NaN
# NAME_TYPE_SUITE                         306219                   7
# NAME_INCOME_TYPE                        307511                   8
# ...

# %%
#bureau dataset - Second Dataset
bureau_balance = pd.read_csv('bureau_balance.csv')

# %%
# Missing Data
missing = pd.DataFrame(bureau_balance.isnull().sum())
missing
# Out:
#                 0
# SK_ID_BUREAU    0
# MONTHS_BALANCE  0
# STATUS          0

# %%
# Summary Statistics
X_describe = bureau_balance.describe(include='all').T

result = pd.concat([X_describe], axis=0).rename(columns={'count': 'Non-missing Count', 'mean': 'Mean', 'std': 'Standard Deviation', 'min': 'Minimum', '25%': '25th percentile', '50%': '50th percentile', '75%': '75th percentile', 'max': 'Maximum', 'unique': 'Unique Values Count', 'top': 'Mode', 'freq': 'Mode Frequency'})
result['Missing Count'] = pd.concat([missing], axis=0)
result['Data Type'] = pd.concat([bureau_balance.dtypes], axis=0)

# Display the result
pd.set_option('display.max_rows', None)
display(result)
# Out:
#                Non-missing Count Unique Values Count Mode Mode Frequency  \
# SK_ID_BUREAU          27299925.0                 NaN  NaN            NaN
# MONTHS_BALANCE        27299925.0                 NaN  NaN            NaN
# STATUS                  27299925                   8    C       13646993
#
#                           Mean Standard Deviation    Minimum 25th percentile  \
# SK_ID_BUREAU    6036297.332974      492348.856904  5001709.0       5730933.0
# MONTHS_BALANCE      -30.741687          23.864509      -96.0           -46.0
# STATUS                     NaN                NaN        NaN             NaN
#
#                50th percentile 75th percentile    Maximum  Missing Count  \
# SK_ID_BUREAU         6070821.0       6431951.0  6842888.0              0
# MONTHS_BALANCE           -25.0           -11.0        0.0              0
# STATUS                     NaN             NaN        NaN              0
#
#                Data Type
# SK_ID_BUREAU       int64
# ...

# %%
bureau = pd.read_csv('bureau.csv')

# %%
# Missing Data
missing = pd.DataFrame(bureau.isnull().sum())
missing
# Out:
#                               0
# SK_ID_CURR                    0
# SK_ID_BUREAU                  0
# CREDIT_ACTIVE                 0
# CREDIT_CURRENCY               0
# DAYS_CREDIT                   0
# CREDIT_DAY_OVERDUE            0
# DAYS_CREDIT_ENDDATE      105553
# DAYS_ENDDATE_FACT        633653
# AMT_CREDIT_MAX_OVERDUE  1124488
# CNT_CREDIT_PROLONG            0
# AMT_CREDIT_SUM               13
# AMT_CREDIT_SUM_DEBT      257669
# AMT_CREDIT_SUM_LIMIT     591780
# AMT_CREDIT_SUM_OVERDUE        0
# CREDIT_TYPE                   0
# DAYS_CREDIT_UPDATE            0
# AMT_ANNUITY             1226791

# %%
# Summary Statistics
X_describe = bureau.describe(include='all').T

result = pd.concat([X_describe], axis=0).rename(columns={'count': 'Non-missing Count', 'mean': 'Mean', 'std': 'Standard Deviation', 'min': 'Minimum', '25%': '25th percentile', '50%': '50th percentile', '75%': '75th percentile', 'max': 'Maximum', 'unique': 'Unique Values Count', 'top': 'Mode', 'freq': 'Mode Frequency'})
result['Missing Count'] = pd.concat([missing], axis=0)
result['Data Type'] = pd.concat([bureau.dtypes], axis=0)

# Display the result
pd.set_option('display.max_rows', None)
display(result)
# Out:
#                        Non-missing Count Unique Values Count             Mode  \
# SK_ID_CURR                     1716428.0                 NaN              NaN
# SK_ID_BUREAU                   1716428.0                 NaN              NaN
# CREDIT_ACTIVE                    1716428                   4           Closed
# CREDIT_CURRENCY                  1716428                   4       currency 1
# DAYS_CREDIT                    1716428.0                 NaN              NaN
# CREDIT_DAY_OVERDUE             1716428.0                 NaN              NaN
# DAYS_CREDIT_ENDDATE            1610875.0                 NaN              NaN
# DAYS_ENDDATE_FACT              1082775.0                 NaN              NaN
# AMT_CREDIT_MAX_OVERDUE          591940.0                 NaN              NaN
# CNT_CREDIT_PROLONG             1716428.0                 NaN              NaN
# AMT_CREDIT_SUM                 1716415.0                 NaN              NaN
# ...

# %%
# installments_payments - Third Dataset
installments_payments = pd.read_csv('installments_payments.csv')

# %%
# Missing Data
missing = pd.DataFrame(installments_payments.isnull().sum())
missing
# Out:
#                            0
# SK_ID_PREV                 0
# SK_ID_CURR                 0
# NUM_INSTALMENT_VERSION     0
# NUM_INSTALMENT_NUMBER      0
# DAYS_INSTALMENT            0
# DAYS_ENTRY_PAYMENT      2905
# AMT_INSTALMENT             0
# AMT_PAYMENT             2905

# %%
# Summary Statistics
X_describe = installments_payments.describe(include='all').T

result = pd.concat([X_describe], axis=0).rename(columns={'count': 'Non-missing Count', 'mean': 'Mean', 'std': 'Standard Deviation', 'min': 'Minimum', '25%': '25th percentile', '50%': '50th percentile', '75%': '75th percentile', 'max': 'Maximum', 'unique': 'Unique Values Count', 'top': 'Mode', 'freq': 'Mode Frequency'})
result['Missing Count'] = pd.concat([missing], axis=0)
result['Data Type'] = pd.concat([installments_payments.dtypes], axis=0)

# Display the result
pd.set_option('display.max_rows', None)
display(result)
# Out:
#                         Non-missing Count          Mean  Standard Deviation  \
# SK_ID_PREV                     13605401.0  1.903365e+06       536202.905546
# SK_ID_CURR                     13605401.0  2.784449e+05       102718.310411
# NUM_INSTALMENT_VERSION         13605401.0  8.566373e-01            1.035216
# NUM_INSTALMENT_NUMBER          13605401.0  1.887090e+01           26.664067
# DAYS_INSTALMENT                13605401.0 -1.042270e+03          800.946284
# DAYS_ENTRY_PAYMENT             13602496.0 -1.051114e+03          800.585883
# AMT_INSTALMENT                 13605401.0  1.705091e+04        50570.254429
# AMT_PAYMENT                    13602496.0  1.723822e+04        54735.783981
#
#                           Minimum  25th percentile  50th percentile  \
# SK_ID_PREV              1000001.0      1434191.000      1896520.000
# SK_ID_CURR               100001.0       189639.000       278685.000
# NUM_INSTALMENT_VERSION        0.0            0.000            1.000
# ...

# %%
# credit_card_balance - Fourth Dataset
credit_card_balance = pd.read_csv('credit_card_balance.csv')

# %%
# Missing Data
missing = pd.DataFrame(credit_card_balance.isnull().sum())
missing
# Out:
#                                  0
# SK_ID_PREV                       0
# SK_ID_CURR                       0
# MONTHS_BALANCE                   0
# AMT_BALANCE                      0
# AMT_CREDIT_LIMIT_ACTUAL          0
# AMT_DRAWINGS_ATM_CURRENT    749816
# AMT_DRAWINGS_CURRENT             0
# AMT_DRAWINGS_OTHER_CURRENT  749816
# AMT_DRAWINGS_POS_CURRENT    749816
# AMT_INST_MIN_REGULARITY     305236
# AMT_PAYMENT_CURRENT         767988
# AMT_PAYMENT_TOTAL_CURRENT        0
# AMT_RECEIVABLE_PRINCIPAL         0
# AMT_RECIVABLE                    0
# AMT_TOTAL_RECEIVABLE             0
# CNT_DRAWINGS_ATM_CURRENT    749816
# CNT_DRAWINGS_CURRENT             0
# CNT_DRAWINGS_OTHER_CURRENT  749816
# CNT_DRAWINGS_POS_CURRENT    749816
# CNT_INSTALMENT_MATURE_CUM   305236
# NAME_CONTRACT_STATUS             0
# SK_DPD                           0
# SK_DPD_DEF                       0

# %%
# Summary Statistics
X_describe = credit_card_balance.describe(include='all').T

result = pd.concat([X_describe], axis=0).rename(columns={'count': 'Non-missing Count', 'mean': 'Mean', 'std': 'Standard Deviation', 'min': 'Minimum', '25%': '25th percentile', '50%': '50th percentile', '75%': '75th percentile', 'max': 'Maximum', 'unique': 'Unique Values Count', 'top': 'Mode', 'freq': 'Mode Frequency'})
result['Missing Count'] = pd.concat([missing], axis=0)
result['Data Type'] = pd.concat([credit_card_balance.dtypes], axis=0)

# Display the result
pd.set_option('display.max_rows', None)
display(result)
# Out:
#                            Non-missing Count Unique Values Count    Mode  \
# SK_ID_PREV                         3840312.0                 NaN     NaN
# SK_ID_CURR                         3840312.0                 NaN     NaN
# MONTHS_BALANCE                     3840312.0                 NaN     NaN
# AMT_BALANCE                        3840312.0                 NaN     NaN
# AMT_CREDIT_LIMIT_ACTUAL            3840312.0                 NaN     NaN
# AMT_DRAWINGS_ATM_CURRENT           3090496.0                 NaN     NaN
# AMT_DRAWINGS_CURRENT               3840312.0                 NaN     NaN
# AMT_DRAWINGS_OTHER_CURRENT         3090496.0                 NaN     NaN
# AMT_DRAWINGS_POS_CURRENT           3090496.0                 NaN     NaN
# AMT_INST_MIN_REGULARITY            3535076.0                 NaN     NaN
# AMT_PAYMENT_CURRENT                3072324.0                 NaN     NaN
# AMT_PAYMENT_TOTAL_CURRENT          3840312.0                 NaN     NaN
# ...

# %%
# POS_CASH_balance - Fifth Dataset
POS_CASH_balance = pd.read_csv('POS_CASH_balance.csv')

# %%
# Missing Data
missing = pd.DataFrame(POS_CASH_balance.isnull().sum())
missing
# Out:
#                            0
# SK_ID_PREV                 0
# SK_ID_CURR                 0
# MONTHS_BALANCE             0
# CNT_INSTALMENT         26071
# CNT_INSTALMENT_FUTURE  26087
# NAME_CONTRACT_STATUS       0
# SK_DPD                     0
# SK_DPD_DEF                 0

# %%
# Summary Statistics
X_describe = POS_CASH_balance.describe(include='all').T

result = pd.concat([X_describe], axis=0).rename(columns={'count': 'Non-missing Count', 'mean': 'Mean', 'std': 'Standard Deviation', 'min': 'Minimum', '25%': '25th percentile', '50%': '50th percentile', '75%': '75th percentile', 'max': 'Maximum', 'unique': 'Unique Values Count', 'top': 'Mode', 'freq': 'Mode Frequency'})
result['Missing Count'] = pd.concat([missing], axis=0)
result['Data Type'] = pd.concat([POS_CASH_balance.dtypes], axis=0)

# Display the result
pd.set_option('display.max_rows', None)
display(result)
# Out:
#                       Non-missing Count Unique Values Count    Mode  \
# SK_ID_PREV                   10001358.0                 NaN     NaN
# SK_ID_CURR                   10001358.0                 NaN     NaN
# MONTHS_BALANCE               10001358.0                 NaN     NaN
# CNT_INSTALMENT                9975287.0                 NaN     NaN
# CNT_INSTALMENT_FUTURE         9975271.0                 NaN     NaN
# NAME_CONTRACT_STATUS           10001358                   9  Active
# SK_DPD                       10001358.0                 NaN     NaN
# SK_DPD_DEF                   10001358.0                 NaN     NaN
#
#                       Mode Frequency            Mean Standard Deviation  \
# SK_ID_PREV                       NaN  1903216.598957      535846.530722
# SK_ID_CURR                       NaN   278403.863306       102763.74509
# MONTHS_BALANCE                   NaN      -35.012588           26.06657
# ...
